# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from time import sleep

import warnings
warnings.filterwarnings('ignore')

from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
"""1. Scrape the details of most viewed videos on YouTube from Wikipedia.
Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
You need to find following details:
A) Rank
B) Name
C) Artist
D) Upload date
E) Views
"""

path ='C:\Program Files\Chromedriver\chromedriver.exe'

browser_1 = webdriver.Chrome(executable_path=path)

browser_1.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

browser_1.maximize_window()

# %%
data = browser_1.find_element(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter']")
alldata=data.text.split('\n')

# %%
dets = alldata[2:32]

# %%
extdata = []
for i in dets:
    extdata.append(i.split())

# %%
ranks=[]
for i in range(0,30):
    ranks.append(extdata[i][0])

# %%
songs=[]
import re
quoted = re.compile('"[^"]*"')
for i in range(0,30):
    for value in quoted.findall(dets[i]):
        songs.append(value)

# %%
remdets = []
alldts = browser_1.find_elements(By.XPATH,"//td")
for i in alldts:
    remdets.append(i.text)

# %%
final_clean_dets = remdets[2:181]

# %%
final_clean_dets[0:20]
# Out:
# ['1.',
#  '"Baby Shark Dance"[4]',
#  "Pinkfong Baby Shark - Kids' Songs & Stories",
#  '11.83',
#  'June 17, 2016',
#  '[A]',
#  '2.',
#  '"Despacito"[7]',
#  'Luis Fonsi',
#  '8.02',
#  'January 12, 2017',
#  '[B]',
#  '3.',
#  '"Johny Johny Yes Papa"[14]',
#  'LooLoo Kids',
#  '6.54',
#  'October 8, 2016',
#  '[C]',
#  '4.',
#  '"Shape of You"[15]']

# %%
artist = []
for i in range(2,179,6):
    artist.append(final_clean_dets[i])

# %%
updt = []
for i in range(4,179,6):
    updt.append(final_clean_dets[i])

# %%
views= []
for i in range(3,179,6):
    views.append(final_clean_dets[i])

# %%
df_vids = pd.DataFrame()
df_vids['ranks']=ranks
df_vids['songs']=songs
df_vids['artist']=artist
df_vids['upload dates']=updt
df_vids['views']=views

df_vids.head(10)
# Out:
#   ranks                                        songs  \
# 0    1.                           "Baby Shark Dance"
# 1    2.                                  "Despacito"
# 2    3.                       "Johny Johny Yes Papa"
# 3    4.                               "Shape of You"
# 4    5.                                  "Bath Song"
# 5    6.                              "See You Again"
# 6    7.                "Phonics Song with Two Words"
# 7    8.                                "Uptown Funk"
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"
# 9   10.                          "Wheels on the Bus"
#
#                                         artist       upload dates  views
# 0  Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016  11.83
# 1                                   Luis Fonsi   January 12, 2017   8.02
# 2                                  LooLoo Kids    October 8, 2016   6.54
# 3                                   Ed Sheeran   January 30, 2017   5.86
# ...

# %%
# saving the dataframe
df_vids.to_csv(r'C:\Users\Lenovo\OneDrive\Desktop\files\topvids.csv')

# %%
"""2. Scrape the details team India’s international fixtures from bcci.tv.
Url = https://www.bcci.tv/.
You need to find following details:
A) Match title (I.e. 1
st ODI)
B) Series
C) Place
D) Date
E) Time
Note: - From bcci.tv home page you have reach to the international fixture page through code."""

# %%
path ='C:\Program Files\Chromedriver\chromedriver.exe'

browser_2 = webdriver.Chrome(executable_path=path)

browser_2.get('https://www.bcci.tv/')

browser_2.maximize_window()

# %%
search_button1 = browser_2.find_element(By.XPATH,"//a[@class='nav-link ']")
search_button1.click()

# %%
fixtures = []
fixdet = browser_2.find_elements(By.XPATH,"//div[@class='fixture-card-main col-lg-3 col-md-6 col-sm-12 ng-scope']")
for i in fixdet:
    fixtures.append(i.text.split('\n'))

# %%
len(fixtures)
# Out:
# 8

# %%
fixtures[0]
# Out:
# ['AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  '11 DEC 2022',
#  '7:00 PM IST',
#  'India Women',
#  'vs',
#  'Australia Women',
#  '2nd T20I - DY Patil Stadium, NAVI MUMBAI',
#  'Match Centre']

# %%
time = []
for i in range(0,8):
    time.append(fixtures[i][2])

# %%
matctit = []
for i in range(0,8):
    matctit.append(fixtures[i][0])

# %%
dates = []
for i in range(0,8):
    dates.append(fixtures[i][1])

# %%
stddet=[]
for i in range(0,8):
    stddet.append(fixtures[i][-2])

# %%
# Out:
# ['vs', 'vs', 'vs', 'vs', 'vs', 'vs', 'vs', 'vs']

# %%
matctit
# Out:
# ['AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  'INDIA TOUR OF BANGLADESH TEST SERIES 2022-23',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  'INDIA TOUR OF BANGLADESH TEST SERIES 2022-23',
#  'SRI LANKA TOUR OF INDIA T20 SERIES 2022-23',
#  'SRI LANKA TOUR OF INDIA T20 SERIES 2022-23']

# %%
dates
# Out:
# ['11 DEC 2022',
#  '14 DEC 2022',
#  '14 DEC 2022',
#  '17 DEC 2022',
#  '20 DEC 2022',
#  '22 DEC 2022',
#  '3 JAN 2023',
#  '5 JAN 2023']

# %%
stddet
# Out:
# ['2nd T20I - DY Patil Stadium, NAVI MUMBAI',
#  '1st Test - Zahur Ahmed Chowdhury Stadium, Chattogram',
#  '3rd T20I - Brabourne - CCI, Mumbai',
#  '4th T20I - Brabourne - CCI, Mumbai',
#  '5th T20I - Brabourne - CCI, Mumbai',
#  '2nd Test - Shere Bangla National Stadium, Mirpur, Dhaka',
#  '1st T20I - Wankhede Stadium, Mumbai',
#  '2nd T20I - Maharashtra Cricket Association Stadium, Pune']

# %%
stadiums=[]
for i in stddet:
    stadiums.append(i.split('-')[1])

# %%
ser=[]
for i in stddet:
    ser.append(i.split('-')[0])
serf = ser[0:8]

# %%
stadiums
# Out:
# [' DY Patil Stadium, NAVI MUMBAI',
#  ' Zahur Ahmed Chowdhury Stadium, Chattogram',
#  ' Brabourne ',
#  ' Brabourne ',
#  ' Brabourne ',
#  ' Shere Bangla National Stadium, Mirpur, Dhaka',
#  ' Wankhede Stadium, Mumbai',
#  ' Maharashtra Cricket Association Stadium, Pune']

# %%
matctit
# Out:
# ['AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  'INDIA TOUR OF BANGLADESH TEST SERIES 2022-23',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  'AUSTRALIA WOMEN TOUR OF INDIA 2022',
#  'INDIA TOUR OF BANGLADESH TEST SERIES 2022-23',
#  'SRI LANKA TOUR OF INDIA T20 SERIES 2022-23',
#  'SRI LANKA TOUR OF INDIA T20 SERIES 2022-23']

# %%
time
# Out:
# ['7:00 PM IST',
#  '9:30 AM IST',
#  '7:00 PM IST',
#  '7:00 PM IST',
#  '7:00 PM IST',
#  '9:30 AM IST',
#  '7:30 PM IST',
#  '7:30 PM IST']

# %%
df_matches = pd.DataFrame()
df_matches['Match title']=matctit
df_matches['Series']=serf
df_matches['Place']=stadiums
df_matches['Date']=dates
df_matches['Time']=time

df_matches.head(10)
# Out:
#                                     Match title     Series  \
# 0            AUSTRALIA WOMEN TOUR OF INDIA 2022  2nd T20I
# 1  INDIA TOUR OF BANGLADESH TEST SERIES 2022-23  1st Test
# 2            AUSTRALIA WOMEN TOUR OF INDIA 2022  3rd T20I
# 3            AUSTRALIA WOMEN TOUR OF INDIA 2022  4th T20I
# 4            AUSTRALIA WOMEN TOUR OF INDIA 2022  5th T20I
# 5  INDIA TOUR OF BANGLADESH TEST SERIES 2022-23  2nd Test
# 6    SRI LANKA TOUR OF INDIA T20 SERIES 2022-23  1st T20I
# 7    SRI LANKA TOUR OF INDIA T20 SERIES 2022-23  2nd T20I
#
#                                             Place         Date         Time
# 0                   DY Patil Stadium, NAVI MUMBAI  11 DEC 2022  7:00 PM IST
# 1       Zahur Ahmed Chowdhury Stadium, Chattogram  14 DEC 2022  9:30 AM IST
# 2                                      Brabourne   14 DEC 2022  7:00 PM IST
# 3                                      Brabourne   17 DEC 2022  7:00 PM IST
# ...

# %%
# saving the dataframe
df_matches.to_csv(r'C:\Users\Lenovo\OneDrive\Desktop\files\bcci.csv')

# %%
"""3. Scrape the details of selenium exception from guru99.com.
Url = https://www.guru99.com/
You need to find following details:
A) Name
B) Description
Note: - From guru99 home page you have to reach to selenium exception handling page through code."""

# %%
import time

# %%
path ='C:\Program Files\Chromedriver\chromedriver.exe'

browser_3 = webdriver.Chrome(executable_path=path)

browser_3.get('https://www.guru99.com/')

browser_3.maximize_window()


selexp = browser_3.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[2]/div[1]/div/ul[1]/li[3]/a")
selexp.click()

time.sleep(3)

"""selcl = browser_3.find_element(By.XPATH,"/html/body/div[6]/div/div[1]/div/div/div/div/div[1]")
selcl.click()

time.sleep(3)
"""
seltut = browser_3.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a")
seltut.click()

time.sleep(3)

seldata = browser_3.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div")

time.sleep(3)
           
allexp=[]
allexp.append(seldata.text.split('\n'))

# %%
allexp
# Out:
# [['What is an Exceptions?',
#   'An exception is an error that happens at the time of execution of a program. However, while running a program, programming languages generates an exception that should be handled to avoid your program to crash.',
#   'The exception indicates that, although the event can occur, this type of event happens infrequently. When the method is not able to handle the Exception, it is thrown to its caller function.',
#   'In this Selenium tutorial, you will learn:',
#   'Types of Exceptions in Selenium Webdriver',
#   '1. ElementNotVisibleException: This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.',
#   '2. ElementNotSelectableException: This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.',
#   '3. NoSuchElementException: This Exception occurs if an element could not be found.',
# ...

# %%
final_d = allexp[0]

# %%
final_data = final_d[5:68]

# %%
len(final_data)
# Out:
# 63

# %%
nameanddisc=[]
for i in final_data:
    nameanddisc.append(i.split(':'))

# %%
nameanddisc
# Out:
# [['1. ElementNotVisibleException',
#   ' This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.'],
#  ['2. ElementNotSelectableException',
#   ' This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.'],
#  ['3. NoSuchElementException',
#   ' This Exception occurs if an element could not be found.'],
#  ['4. NoSuchFrameException',
#   ' This Exception occurs if the frame target to be switched to does not exist.'],
#  ['5. NoAlertPresentException',
#   ' This Exception occurs when you switch to no presented alert.'],
#  ['EXPLORE MORE'],
#  ['Learn Java Programming with Beginners Tutorial'],
#  ['08', '32'],
#  ['Linux Tutorial for Beginners', ' Introduction to Linux Operating...'],
#  ['01', '35'],
#  ['What is Integration Testing Software Testing Tutorial'],
#  ['03', '04'],
#  ['What is JVM (Java Virtual Machine) with Architecture JAVA...'],
# ...

# %%
time.sleep(3)

names=[]
for i in range(0,62,1):
    names.append(nameanddisc[i][0])

# %%
names
# Out:
# ['1. ElementNotVisibleException',
#  '2. ElementNotSelectableException',
#  '3. NoSuchElementException',
#  '4. NoSuchFrameException',
#  '5. NoAlertPresentException',
#  'EXPLORE MORE',
#  'Learn Java Programming with Beginners Tutorial',
#  '08',
#  'Linux Tutorial for Beginners',
#  '01',
#  'What is Integration Testing Software Testing Tutorial',
#  '03',
#  'What is JVM (Java Virtual Machine) with Architecture JAVA...',
#  '02',
#  'How to write a TEST CASE Software Testing Tutorial',
#  '01',
#  'Seven Testing Principles Software Testing',
#  '05',
#  'Linux File Permissions Commands with Examples',
#  '13',
#  'How to use Text tool in Photoshop CC Tutorial',
#  '08',
#  'What is NoSQL Database Tutorial',
#  '02',
#  'Important Linux Commands for Beginners Linux Tutorial',
#  '15',
#  '6. NoSuchWindowException',
#  '7. StaleElementReferenceException',
#  '8. SessionNotFoundException',
#  '9. TimeoutException',
#  '10. WebDriverException',
#  '11. ConnectionClosedException',
# ...

# %%
n1 = names[0:5]
n1
# Out:
# ['1. ElementNotVisibleException',
#  '2. ElementNotSelectableException',
#  '3. NoSuchElementException',
#  '4. NoSuchFrameException',
#  '5. NoAlertPresentException']

# %%
n2 = names[26:62]
n2
# Out:
# ['6. NoSuchWindowException',
#  '7. StaleElementReferenceException',
#  '8. SessionNotFoundException',
#  '9. TimeoutException',
#  '10. WebDriverException',
#  '11. ConnectionClosedException',
#  '12. ElementClickInterceptedException',
#  '13. ElementNotInteractableException',
#  '14. ErrorInResponseException',
#  '15. ErrorHandler.UnknownServerException',
#  '16. ImeActivationFailedException',
#  '17. ImeNotAvailableException',
#  '18. InsecureCertificateException',
#  '19. InvalidArgumentException',
#  '20. InvalidCookieDomainException',
#  '21. InvalidCoordinatesException',
#  '22. InvalidElementStateException',
#  '23. InvalidSessionIdException',
#  '24. InvalidSwitchToTargetException',
#  '25. JavascriptException',
#  '26. JsonException',
#  '27. NoSuchAttributeException',
#  '28. MoveTargetOutOfBoundsException',
#  '29. NoSuchContextException',
#  '30. NoSuchCookieException',
#  '31. NotFoundException',
#  '32. RemoteDriverServerException',
#  '33. ScreenshotException',
# ...

# %%
nf=n1+n2
nf
# Out:
# ['1. ElementNotVisibleException',
#  '2. ElementNotSelectableException',
#  '3. NoSuchElementException',
#  '4. NoSuchFrameException',
#  '5. NoAlertPresentException',
#  '6. NoSuchWindowException',
#  '7. StaleElementReferenceException',
#  '8. SessionNotFoundException',
#  '9. TimeoutException',
#  '10. WebDriverException',
#  '11. ConnectionClosedException',
#  '12. ElementClickInterceptedException',
#  '13. ElementNotInteractableException',
#  '14. ErrorInResponseException',
#  '15. ErrorHandler.UnknownServerException',
#  '16. ImeActivationFailedException',
#  '17. ImeNotAvailableException',
#  '18. InsecureCertificateException',
#  '19. InvalidArgumentException',
#  '20. InvalidCookieDomainException',
#  '21. InvalidCoordinatesException',
#  '22. InvalidElementStateException',
#  '23. InvalidSessionIdException',
#  '24. InvalidSwitchToTargetException',
#  '25. JavascriptException',
#  '26. JsonException',
#  '27. NoSuchAttributeException',
# ...

# %%
len(nameanddisc)
# Out:
# 63

# %%
nameanddisc
# Out:
# [['1. ElementNotVisibleException',
#   ' This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.'],
#  ['2. ElementNotSelectableException',
#   ' This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.'],
#  ['3. NoSuchElementException',
#   ' This Exception occurs if an element could not be found.'],
#  ['4. NoSuchFrameException',
#   ' This Exception occurs if the frame target to be switched to does not exist.'],
#  ['5. NoAlertPresentException',
#   ' This Exception occurs when you switch to no presented alert.'],
#  ['EXPLORE MORE'],
#  ['Learn Java Programming with Beginners Tutorial'],
#  ['08', '32'],
#  ['Linux Tutorial for Beginners', ' Introduction to Linux Operating...'],
#  ['01', '35'],
#  ['What is Integration Testing Software Testing Tutorial'],
#  ['03', '04'],
#  ['What is JVM (Java Virtual Machine) with Architecture JAVA...'],
# ...

# %%
nd1 = nameanddisc[0:4]
nd2 = nameanddisc[26:62]
nf=nd1+nd2

# %%
len(nf)
# Out:
# 40

# %%
des = []
for i in range(0,40):
    des.append(nf[i][1])

# %%
des
# Out:
# [' This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.',
#  ' This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.',
#  ' This Exception occurs if an element could not be found.',
#  ' This Exception occurs if the frame target to be switched to does not exist.',
#  ' This Exception occurs if the window target to be switch does not exist.',
#  ' This Selenium exception occurs happens when the web element is detached from the current DOM.',
#  ' The WebDriver is acting after you quit the browser.',
#  ' Thrown when there is not enough time for a command to be completed. For Example, the element searched wasn’t found in the specified time.',
#  ' This Exception takes place when the WebDriver is acting right after you close the browser.',
#  ' This type of Exception takes place when there is a disconnection in the driver.',
# ...

# %%
df_exp = pd.DataFrame()
df_exp['Names']=nf
df_exp['Description']=des

df_exp.head(10)
# Out:
#                                                Names  \
# 0  [1. ElementNotVisibleException,  This type of ...
# 1  [2. ElementNotSelectableException,  This Selen...
# 2  [3. NoSuchElementException,  This Exception oc...
# 3  [4. NoSuchFrameException,  This Exception occu...
# 4  [6. NoSuchWindowException,  This Exception occ...
# 5  [7. StaleElementReferenceException,  This Sele...
# 6  [8. SessionNotFoundException,  The WebDriver i...
# 7  [9. TimeoutException,  Thrown when there is no...
# 8  [10. WebDriverException,  This Exception takes...
# 9  [11. ConnectionClosedException,  This type of ...
#
#                                          Description
# 0   This type of Selenium exception occurs when a...
# 1   This Selenium exception occurs when an elemen...
# 2   This Exception occurs if an element could not...
# 3   This Exception occurs if the frame target to ...
# 4   This Exception occurs if the window target to...
# 5   This Selenium exception occurs happens when t...
# ...

# %%
# saving the dataframe
df_exp.to_csv(r'C:\Users\Lenovo\OneDrive\Desktop\files\excep.csv')

# %%
"""4. Scrape the details of State-wise GDP of India from statisticstime.com.
Url = http://statisticstimes.com/
You have to find following details:
A) Rank
B) State
C) GSDP(18-19)- at current prices
D) GSDP(19-20)- at current prices
E) Share(18-19)
F) GDP($ billion)
Note: - From statisticstimes home page you have to reach to economy page through code."""

# %%
path ='C:\Program Files\Chromedriver\chromedriver.exe'

browser_4 = webdriver.Chrome(executable_path=path)

browser_4.get('http://statisticstimes.com/')

browser_4.maximize_window()

dropd = browser_4.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/button")
dropd.click()

time.sleep(3)

indeco = browser_4.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]")
indeco.click()

time.sleep(3)

"""indstgdp = browser_4.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
indstgdp.click()

time.sleep(3)"""
# Out:
# 'indstgdp = browser_4.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")\nindstgdp.click()\n\ntime.sleep(3)'

# %%
indstgdp = browser_4.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
indstgdp.click()

# %%
rank = []
rk = browser_4.find_elements(By.XPATH,"//td[@class='data1']")
for i in rk:
    rank.append(i.text)

# %%
rank_f = rank[0:33]

# %%
states = []
st = browser_4.find_elements(By.XPATH,"//td[@class='name']")
for i in st:
    states.append(i.text)

# %%
states
# Out:
# ['Maharashtra',
#  'Tamil Nadu',
#  'Uttar Pradesh',
#  'Gujarat',
#  'Karnataka',
#  'West Bengal',
#  'Rajasthan',
#  'Andhra Pradesh',
#  'Telangana',
#  'Madhya Pradesh',
#  'Kerala',
#  'Delhi',
#  'Haryana',
#  'Bihar',
#  'Punjab',
#  'Odisha',
#  'Assam',
#  'Chhattisgarh',
#  'Jharkhand',
#  'Uttarakhand',
#  'Jammu & Kashmir',
#  'Himachal Pradesh',
#  'Goa',
#  'Tripura',
#  'Chandigarh',
#  'Puducherry',
#  'Meghalaya',
#  'Sikkim',
#  'Manipur',
#  'Nagaland',
#  'Arunachal Pradesh',
#  'Mizoram',
#  'Andaman & Nicobar Islands',
#  'India',
#  'Maharashtra',
#  'Tamil Nadu',
#  'Uttar Pradesh',
#  'Karnataka',
#  'Gujarat',
#  'West Bengal',
#  'Rajasthan',
#  'Telangana',
#  'Andhra Pradesh',
#  'Madhya Pradesh',
#  'Kerala',
#  'Delhi',
#  'Haryana',
#  'Bihar',
#  'Punjab',
#  'Odisha',
#  'Assam',
#  'Jharkhand',
#  'Chhattisgarh',
#  'Uttarakhand',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Goa',
#  'Tripura',
#  'Chandigarh',
#  'Puducherry',
#  'Meghalaya',
# ...

# %%
gsdp1920 = []
gsdp = browser_4.find_elements(By.XPATH,"//td[@class='data']")
for i in gsdp:
    gsdp1920.append(i.text)

# %%
gsdp1920
# Out:
# ['-',
#  '13.94%',
#  '399.921',
#  '-',
#  '2,039,074',
#  '1,845,853',
#  '8.63%',
#  '247.629',
#  '1,312,929',
#  '1,215,307',
#  '1,687,818',
#  '8.39%',
#  '240.726',
#  '1,166,817',
#  '1,123,982',
#  '-',
#  '7.96%',
#  '228.290',
#  '-',
#  '1,186,379',
#  '1,631,977',
#  '7.91%',
#  '226.806',
#  '1,156,039',
#  '1,091,077',
#  '1,253,832',
#  '5.77%',
#  '165.556',
#  '793,223',
#  '739,525',
#  '1,020,989',
#  '4.99%',
#  '143.179',
#  '711,627',
#  '677,428',
#  '972,782',
#  '4.57%',
#  '131.083',
#  '672,018',
#  '621,301',
#  '969,604',
#  '4.56%',
#  '130.791',
#  '663,258',
#  '612,828',
#  '906,672',
#  '4.29%',
#  '122.977',
#  '561,801',
#  '522,009',
#  '-',
#  '4.14%',
#  '118.733',
#  '-',
#  '559,412',
#  '856,112',
#  '4.10%',
#  '117.703',
#  '634,408',
#  '590,569',
#  '831,610',
#  '3.89%',
#  '111.519',
#  '572,240',
#  '531,085',
#  '611,804',
#  '2.81%',
#  '80.562',
#  '414,977',
#  '375,651',
#  '574,760',
#  '2.79%',
#  '79.957',
#  '418,868',
# ...

# %%
gdpbillion_f = gsdp1920[2:165:5]

# %%
gdpbillion_f
# Out:
# ['399.921',
#  '247.629',
#  '240.726',
#  '228.290',
#  '226.806',
#  '165.556',
#  '143.179',
#  '131.083',
#  '130.791',
#  '122.977',
#  '118.733',
#  '117.703',
#  '111.519',
#  '80.562',
#  '79.957',
#  '74.098',
#  '47.982',
#  '46.187',
#  '45.145',
#  '37.351',
#  '23.690',
#  '23.369',
#  '11.115',
#  '7.571',
#  '6.397',
#  '5.230',
#  '5.086',
#  '4.363',
#  '4.233',
#  '4.144',
#  '3.737',
#  '3.385',
#  '-']

# %%
share1819=[]
for i in range(1,309,5):
    share1819.append(gsdp1920[i])

# %%
share_f = share1819[0:33]

# %%
gsdp=[]
for i in range(0,309,5):
    gsdp.append(gsdp1920[i])

# %%
gsdp1920_f = gsdp[0:33]

# %%
gsdp1819 = []
gsdp18 = browser_4.find_elements(By.XPATH,"//td[@class='data sorting_1']")
for i in gsdp18:
    gsdp1819.append(i.text)

# %%
gsdp_f = gsdp1819[0:33]

# %%
gsdp1920
# Out:
# ['-',
#  '13.94%',
#  '399.921',
#  '-',
#  '2,039,074',
#  '1,845,853',
#  '8.63%',
#  '247.629',
#  '1,312,929',
#  '1,215,307',
#  '1,687,818',
#  '8.39%',
#  '240.726',
#  '1,166,817',
#  '1,123,982',
#  '-',
#  '7.96%',
#  '228.290',
#  '-',
#  '1,186,379',
#  '1,631,977',
#  '7.91%',
#  '226.806',
#  '1,156,039',
#  '1,091,077',
#  '1,253,832',
#  '5.77%',
#  '165.556',
#  '793,223',
#  '739,525',
#  '1,020,989',
#  '4.99%',
#  '143.179',
#  '711,627',
#  '677,428',
#  '972,782',
#  '4.57%',
#  '131.083',
#  '672,018',
#  '621,301',
#  '969,604',
#  '4.56%',
#  '130.791',
#  '663,258',
#  '612,828',
#  '906,672',
#  '4.29%',
#  '122.977',
#  '561,801',
#  '522,009',
#  '-',
#  '4.14%',
#  '118.733',
#  '-',
#  '559,412',
#  '856,112',
#  '4.10%',
#  '117.703',
#  '634,408',
#  '590,569',
#  '831,610',
#  '3.89%',
#  '111.519',
#  '572,240',
#  '531,085',
#  '611,804',
#  '2.81%',
#  '80.562',
#  '414,977',
#  '375,651',
#  '574,760',
#  '2.79%',
#  '79.957',
#  '418,868',
# ...

# %%
len(rank_f)
# Out:
# 33

# %%
states_f = states[0:33]
len(states_f)
# Out:
# 33

# %%
len(gsdp1920_f)
# Out:
# 33

# %%
len(gsdp_f)
# Out:
# 33

# %%
len(share_f)
# Out:
# 33

# %%
len(gdpbillion_f)
# Out:
# 33

# %%
df_gdp = pd.DataFrame()
df_gdp['Rank'] = rank_f
df_gdp['States'] = states_f
df_gdp['GSDP 1920'] = gsdp1920_f
df_gdp['GSDP 1819'] = gsdp_f
df_gdp['Share Percent'] = share_f
df_gdp['GDP in Billions'] = gdpbillion_f

# %%
df_gdp
# Out:
#    Rank                     States  GSDP 1920  GSDP 1819 Share Percent  \
# 0     1                Maharashtra          -  2,632,792        13.94%
# 1     2                 Tamil Nadu  1,845,853  1,630,208         8.63%
# 2     3              Uttar Pradesh  1,687,818  1,584,764         8.39%
# 3     4                    Gujarat          -  1,502,899         7.96%
# 4     5                  Karnataka  1,631,977  1,493,127         7.91%
# 5     6                West Bengal  1,253,832  1,089,898         5.77%
# 6     7                  Rajasthan  1,020,989    942,586         4.99%
# 7     8             Andhra Pradesh    972,782    862,957         4.57%
# 8     9                  Telangana    969,604    861,031         4.56%
# 9    10             Madhya Pradesh    906,672    809,592         4.29%
# 10   11                     Kerala          -    781,653         4.14%
# 11   12                      Delhi    856,112    774,870         4.10%
# ...

# %%
# saving the dataframe
df_gdp.to_csv(r'C:\Users\Lenovo\OneDrive\Desktop\files\gdp.csv')

# %%
"""5.Scrape the details of trending repositories on Github.com.
Url = https://github.com/
You have to find the following details:
A) Repository title
B) Repository description
C) Contributors count
D) Language used
"""

# %%
path ='C:\Program Files\Chromedriver\chromedriver.exe'

browser_5 = webdriver.Chrome(executable_path=path)

browser_5.get('https://github.com/trending')

browser_5.maximize_window()

# %%
reps = []
repname = browser_5.find_elements(By.XPATH,"//span[@class='text-normal']")
for i in repname:
    reps.append(i.text)
desc = []
ds = browser_5.find_elements(By.XPATH,"//p[@class='col-9 color-fg-muted my-1 pr-4']")
for j in ds:
    desc.append(j.text)
content=[]
con = browser_5.find_elements(By.XPATH,"//div[@class='f6 color-fg-muted mt-2']")
for l in con:
    content.append(l.text)

# %%
ct_f = []
for i in content:
    ct_f.append(i.split(' '))

# %%
ct_f
# Out:
# [['TypeScript', '2,433', '391', 'Built', 'by\n730', 'stars', 'today'],
#  ['Go', '426', '98', 'Built', 'by\n128', 'stars', 'today'],
#  ['C++', '1,578', '31', 'Built', 'by\n491', 'stars', 'today'],
#  ['Java', '18,970', '3,471', 'Built', 'by\n453', 'stars', 'today'],
#  ['TypeScript', '3,575', '139', 'Built', 'by\n232', 'stars', 'today'],
#  ['C++', '7,169', '858', 'Built', 'by\n121', 'stars', 'today'],
#  ['Jupyter', 'Notebook', '189', '14', 'Built', 'by\n45', 'stars', 'today'],
#  ['TypeScript', '556', '85', 'Built', 'by\n184', 'stars', 'today'],
#  ['Lua', '2,502', '1,627', 'Built', 'by\n9', 'stars', 'today'],
#  ['Rust', '16,206', '377', 'Built', 'by\n115', 'stars', 'today'],
#  ['JavaScript', '444', '48', 'Built', 'by\n80', 'stars', 'today'],
#  ['JavaScript', '197', '33', 'Built', 'by\n70', 'stars', 'today'],
#  ['Python', '227', '17', 'Built', 'by\n40', 'stars', 'today'],
#  ['Perl', '672', '1,056', 'Built', 'by\n7', 'stars', 'today'],
# ...

# %%
languages=[]
for i in range(0,25):
    languages.append(ct_f[i][0])
    ct_f[0][0]

# %%
len(languages)
# Out:
# 25

# %%
df_rep= pd.DataFrame()
df_rep['REpository Name'] = reps
df_rep['Description of repository'] = desc
df_rep['Language'] = languages
df_rep['Contributions'] = content

# %%
df_rep
# Out:
#               REpository Name  \
# 0              fuergaosi233 /
# 1                 869413421 /
# 2                   exaloop /
# 3                     doocs /
# 4                    teaxyz /
# 5                   Tencent /
# 6               cloneofsimo /
# 7                 AutumnWhj /
# 8   PathOfBuildingCommunity /
# 9                 surrealdb /
# 10                 gragland /
# 11             wangrongding /
# 12               mohammadpz /
# 13          holbertonschool /
# 14                humanloop /
# 15           rawandahmad698 /
# 16              pulsar-edit /
# 17               bupticybee /
# 18                        f /
# 19                 louislam /
# 20              pichenettes /
# 21                acheong08 /
# 22              paradigmxyz /
# 23                bytedance /
# 24               AmazingAng /
#
#                             Description of repository    Language  \
# 0                   Use ChatGPT On Wechat via wechaty  TypeScript
# ...

# %%
# saving the dataframe
df_rep.to_csv(r'C:\Users\Lenovo\OneDrive\Desktop\files\repository.csv')

# %%
"""6. Scrape the details of top 100 songs on billiboard.com.
Url = https:/www.billboard.com/
You have to find the following details:
A) Song name
B) Artist name
C) Last week rank
D) Peak rank
E) Weeks on board
Note: - From the home page you have to click on the charts option then hot 100-page link through code.

"""

# %%
from bs4 import BeautifulSoup as soup

url = 'https://www.billboard.com/charts/hot-100'

response1 = requests.get(url)
htmlresponse1 = response1.content
soup1 = BeautifulSoup(htmlresponse1,'html.parser')

# Grabs all information related to the top 100 songs
containers = soup1.select('article[class*=chart]') # *= means contains

filename = 'billboard_hot_100.csv'
f = open(filename, 'w') # w = write

headers = 'Song, Artist, Last Week, Peak Position, Weeks on Chart\n'

f.write(headers)

# Asks the user if he/she wants the data to be printed to the console
while True:
    print_data = input('Would you like the data to be printed to the console? ')
    if print_data.lower() == 'yes' or print_data.lower() == 'y':
        print_data = True
        print('\nPrinting this week\'s HOTTEST 100 songs...')
        break
    elif print_data.lower() == 'no' or print_data.lower() == 'n':
        print_data = False
        print('\nScraping this week\'s HOTTEST 100 songs...')
        break
    else:
        print('Sorry, I didn\'t get that.')

chart_position = 1

# Loops through each container
for container in containers:

    # Container storing the song name and artist name
    song_container = container.find('div', {'class': 'chart-row__title'})

    # Grabs the song name
    song = song_container.h2.text
    
    # Grabs the artist name
    try:
        artist = song_container.a.text.strip()
    except AttributeError:
        artist = song_container.span.text.strip()

    # Grabs the song's position last week
    last_week_container = container.find('div', {'class': 'chart-row__last-week'})
    last_week = last_week_container.find('span', {'class': 'chart-row__value'}).text

    # Grabs the song's peak position
    peak_position_container = container.find('div', {'class': 'chart-row__top-spot'})
    peak_position = peak_position_container.find('span', {'class': 'chart-row__value'}).text

    # Grabs the song's duration in the hot 100 (in weeks)
    weeks_on_chart_container = container.find('div', {'class': 'chart-row__weeks-on-chart'})
    weeks_on_chart = weeks_on_chart_container.find('span', {'class': 'chart-row__value'}).text

    # Prints the chart position, song name, artist name, and related stats
    if print_data:
        print('\nPosition: #{}'.format(chart_position))
        print('Song: {}'.format(song))
        print('Artist: {}'.format(artist))
        print('Last Week: {}'.format(last_week))
        print('Peak Position: {}'.format(peak_position))
        print('Weeks on Chart: {}'.format(weeks_on_chart))

    chart_position += 1

    f.write('\"' + song + '\",\"' + artist.replace('Featuring', 'Feat.') + '\",' + last_week + ',' + peak_position + ',' + weeks_on_chart + '\n')

f.close()

print('\nWeb scraped data saved to {}'.format(filename))
# Out:
# Would you like the data to be printed to the console? yes
#
# Printing this week's HOTTEST 100 songs...
#
# Web scraped data saved to billboard_hot_100.csv

# %%
"""7. Scrape the details of Data science recruiters from naukri.com.
Url = https://www.naukri.com/
You have to find the following details:
A) Name
B) Designation
C) Company
D) Skills they hire for
E) Location
Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
click on search. All this should be done through code"""

# %%
browser_7 = webdriver.Chrome(executable_path=path)

browser_7.get('https://www.naukri.com/data-scientist-recruiters')

browser_7.maximize_window()

# %%
rec_det = []
det = browser_7.find_elements(By.XPATH,"//p[@class='highlightable']")
for i in det:
    rec_det.append(i.text.split('\n'))

# %%
rec_det[0]
# Out:
# ['Tanushree', 'Lead Recruiter', 'RecRoots', 'Noida']

# %%
names=[]
for i in rec_det:
    names.append(i[0])
desig=[]
for j in rec_det:
    desig.append(j[1])
comp=[]
for k in rec_det:
    comp.append(k[2])

# %%
skills=[]
skl = browser_7.find_elements(By.XPATH,"//div[@class='hireSec highlightable']")
for l in skl:
    skills.append(l.text)

# %%
df_rec= pd.DataFrame()
df_rec['Name'] = names
df_rec['Designation'] = desig
df_rec['Company'] = comp
df_rec['Skills'] = skills

# %%
df_rec.head(10)
# Out:
#                 Name                             Designation  \
# 0          Tanushree                          Lead Recruiter
# 1      sashi bhushan                       Senior Specialist
# 2             Bitapi                HR and Operation Manager
# 3     Gajendra Singh  Head of Recruitment - Product &amp;...
# 4  Sadashiv Kulkarni                              Company HR
# 5        Invelopment                              Company HR
# 6  Anjali Srivastava                             Director HR
# 7         Helly Vyas                     HR Business Partner
# 8       Ashish Verma        Senior Associate Human Resources
# 9      Shiva Kumar N                                 Founder
#
#                                  Company  \
# 0                               RecRoots
# 1                                  Wipro
# 2                                 Anvaya
# 3  A Leading of Product Start-UP Company
# 4            Digitially Insights Pvt Ltd
# ...

# %%
# saving the dataframe
df_rec.to_csv(r'C:\Users\Lenovo\OneDrive\Desktop\files\recruiter.csv')

# %%
"""8. Scrape the details of Highest selling novels.
Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
You have to find the following details:
A) Book name
B) Author name
C) Volumes sold
D) Publisher
E) Genre"""

# %%
browser_8 = webdriver.Chrome(executable_path=path)

browser_8.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/')

browser_8.maximize_window()

# %%
# This pagfe is not found

# %%
"""9. Scrape the details most watched tv series of all time from imdb.com.
Url = https://www.imdb.com/list/ls095964455/
You have to find the following details:
A) Name
B) Year span
C) Genre
D) Run time
E) Ratings
F) Votes
"""

# %%
browser_9 = webdriver.Chrome(executable_path=path)

browser_9.get('https://www.imdb.com/list/ls095964455/')

browser_9.maximize_window()

# %%
alldet = []
dt = browser_9.find_elements(By.XPATH,"//div[@class='lister-item-content']")
for i in dt:
    alldet.append(i.text.split('\n'))

# %%
alldet[0]
# Out:
# ['1. Game of Thrones (2011–2019)',
#  'TV-MA | 57 min | Action, Adventure, Drama',
#  '9.2',
#  'Rate',
#  'Nine noble families fight for control over the lands of Westeros, while an ancient enemy returns after being dormant for millennia.',
#  'Stars: Emilia Clarke, Peter Dinklage, Kit Harington, Lena Headey',
#  'Votes: 2,091,240']

# %%
names9=[]
for p in alldet:
    names9.append(p[0])
genre=[]
for k in alldet:
    genre.append(k[1])
rating9=[]
for m in alldet:
    rating9.append(k[2])
votes=[]
for n in alldet:
    votes.append(k[6])

# %%
df_tv= pd.DataFrame()
df_tv['Names'] = names9
df_tv['genre'] = genre
df_tv['rating'] = rating9
df_tv['votes'] = votes

# %%
df_tv
# Out:
#                                              Names  \
# 0                   1. Game of Thrones (2011–2019)
# 1                      2. Stranger Things (2016– )
# 2                  3. The Walking Dead (2010–2022)
# 3                    4. 13 Reasons Why (2017–2020)
# 4                           5. The 100 (2014–2020)
# ..                                             ...
# 95                           96. Reign (2013–2017)
# 96  97. A Series of Unfortunate Events (2017–2019)
# 97                     98. Criminal Minds (2005– )
# 98           99. Scream: The TV Series (2015–2019)
# 99          100. The Haunting of Hill House (2018)
#
#                                         genre rating           votes
# 0   TV-MA | 57 min | Action, Adventure, Drama    8.6  Votes: 245,425
# 1     TV-14 | 51 min | Drama, Fantasy, Horror    8.6  Votes: 245,425
# 2    TV-MA | 44 min | Drama, Horror, Thriller    8.6  Votes: 245,425
# 3   TV-MA | 60 min | Drama, Mystery, Thriller    8.6  Votes: 245,425
# ...

# %%
# saving the dataframe
df_tv.to_csv(r'C:\Users\Lenovo\OneDrive\Desktop\files\shows.csv')

# %%
"""10. Details of Datasets from UCI machine learning repositories.
Url = https://archive.ics.uci.edu/
You have to find the following details:
A) Dataset name
B) Data type
C) Task
D) Attribute type
E) No of instances
F) No of attribute
G) Year
Note: - from the home page you have to go to the ShowAllDataset page through code"""

# %%
browser_10 = webdriver.Chrome(executable_path=path)

browser_10.get('https://archive.ics.uci.edu/')

browser_10.maximize_window()

# %%
viewall = browser_10.find_element(By.XPATH,"/html/body/table[1]/tbody/tr/td[2]/span[2]/a")
viewall.click()

# %%
lviewall = browser_10.find_element(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")
lviewall.click()

# %%
datas = []
elems = browser_10.find_elements(By.CLASS_NAME,"normal")
for i in elems:
    datas.append(i.text.split(':'))

# %%
len(datas)
# Out:
# 634

# %%
lists = datas[9:631]

# %%
len(lists)
# Out:
# 622

# %%
lists
# Out:
# [['1. 2.4 GHZ Indoor Channel Measurements',
#   ' Measurement of the S21,consists of 10 sweeps, each sweep contains 601 frequency points with spacing of 0.167MHz to cover a 100MHz band centered at 2.4GHz.'],
#  ['2. 3D Road Network (North Jutland, Denmark)',
#   ' 3D road network with highly accurate elevation information (+-20cm) from Denmark used in eco-routing and fuel/Co2-estimation routing algorithms.'],
#  ['3. 3W dataset',
#   ' The first realistic and public dataset with rare undesirable real events in oil wells.'],
#  ['4. 9mers from cullpdb',
#   ' Provide a short description of your data set (less than 200 characters).'],
#  ['5. ',
#   ' Simulated Data set of Iraqi tourism places',
#   ' Simulated Data set of Iraqi tourism places with their position (longitude,latitude)and type of interest for each place'],
#  ['6. A study of Asian Religious and Biblical Texts',
# ...

# %%
names10 = []
for i in range(0,622):
    names10.append(lists[i][0])

# %%
names10
# Out:
# ['1. 2.4 GHZ Indoor Channel Measurements',
#  '2. 3D Road Network (North Jutland, Denmark)',
#  '3. 3W dataset',
#  '4. 9mers from cullpdb',
#  '5. ',
#  '6. A study of Asian Religious and Biblical Texts',
#  '7. AAAI 2013 Accepted Papers',
#  '8. AAAI 2014 Accepted Papers',
#  '9. Abalone',
#  '10. Abscisic Acid Signaling Network',
#  '11. Absenteeism at work',
#  '12. Accelerometer',
#  '13. Activities of Daily Living (ADLs) Recognition Using Binary Sensors',
#  '14. Activity Recognition from Single Chest-Mounted Accelerometer',
#  '15. Activity Recognition system based on Multisensor data fusion (AReM)',
#  '16. Activity recognition using wearable physiological measurements',
#  '17. Activity recognition with healthy older people using a batteryless wearable sensor',
#  '18. Acute Inflammations',
#  '19. Adult',
#  '20. AI4I 2020 Predictive Maintenance Dataset',
#  '21. Air Quality',
#  '22. Air quality',
#  '23. Airfoil Self-Noise',
#  '24. Alcohol QCM Sensor Dataset',
# ...

# %%
des10 = []
for j in range(0,622):
    des10.append(lists[j][1])

# %%
des10
# Out:
# [' Measurement of the S21,consists of 10 sweeps, each sweep contains 601 frequency points with spacing of 0.167MHz to cover a 100MHz band centered at 2.4GHz.',
#  ' 3D road network with highly accurate elevation information (+-20cm) from Denmark used in eco-routing and fuel/Co2-estimation routing algorithms.',
#  ' The first realistic and public dataset with rare undesirable real events in oil wells.',
#  ' Provide a short description of your data set (less than 200 characters).',
#  ' Simulated Data set of Iraqi tourism places',
#  ' Mainly from Project Gutenberg, we combine Upanishads, Yoga Sutras, Buddha Sutras, Tao Te Ching and Book of Wisdom, Book of Proverbs, Book of Ecclesiastes and Book of Ecclesiasticus',
#  " This data set compromises the metadata for the 2013 AAAI conference's accepted papers (main track only), including paper titles, abstracts, and keywords of varying granularity.",
# ...

# %%
df_dsets= pd.DataFrame()
df_dsets['Names'] = names10
df_dsets['Description'] = des10

# %%
df_dsets
# Out:
#                                                  Names  \
# 0               1. 2.4 GHZ Indoor Channel Measurements
# 1          2. 3D Road Network (North Jutland, Denmark)
# 2                                        3. 3W dataset
# 3                                4. 9mers from cullpdb
# 4                                                  5.
# ..                                                 ...
# 617  618. Youtube cookery channels viewers comments...
# 618         619. YouTube Multiview Video Games Dataset
# 619                       620. YouTube Spam Collection
# 620                               621. Z-Alizadeh Sani
# 621                                           622. Zoo
#
#                                            Description
# 0     Measurement of the S21,consists of 10 sweeps,...
# 1     3D road network with highly accurate elevatio...
# 2     The first realistic and public dataset with r...
# 3     Provide a short description of your data set ...
# ...

# %%
# saving the dataframe
df_dsets.to_csv(r'C:\Users\Lenovo\OneDrive\Desktop\files\datasets.csv')
